# %% [markdown]
# <a href="https://colab.research.google.com/github/daqichen/CIFAR10/blob/main/Final_Model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Classification Model

# %%
import numpy as np
import matplotlib.pyplot as plt
from keras.datasets import cifar10
from keras.models import Sequential
from keras.layers import BatchNormalization, Conv2D, Dense, Dropout, Flatten, MaxPooling2D
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.optimizers import Adam
from keras.preprocessing.image import ImageDataGenerator
# %matplotlib inline

# %%
def data_loader(test=False):
  # load dataset
  (trainX, trainY), (testX, testY) = cifar10.load_data()
  # normalize x values
  trainX, testX = trainX.astype('float32')/255.0, testX.astype('float32')/255.0
  # one hot encode y values
  trainY, testY = to_categorical(trainY), to_categorical(testY)
  if (test):
    # return train set and test set
    return trainX, trainY, testX, testY
  else:
    # randomly sample 20% of data from train set
    mask_indices = np.random.choice(np.arange(trainX.shape[0]), size=int(trainX.shape[0] * 0.2), replace=False)
    mask_arr = np.zeros(trainX.shape[0])
    mask_arr[mask_indices] = 1
    # create validation set using random sample
    valX, valY = trainX[mask_arr == 1], trainY[mask_arr == 1]
    # remove random sample from train set
    trainX, trainY = trainX[mask_arr == 0], trainY[mask_arr == 0]
    # return train set and validation set
    return trainX, trainY, valX, valY

# %%
def data_generator(trainX, trainY, batch_size=64, width_shift_range=0.1, height_shift_range=0.1, horizontal_flip=True):
  # create data iterator
  data_gen = ImageDataGenerator(width_shift_range=width_shift_range, height_shift_range=height_shift_range, horizontal_flip=horizontal_flip)
  data_iter = data_gen.flow(trainX, trainY, batch_size=batch_size)
  # calculate steps per epoch
  steps_per_epoch = int(trainX.shape[0]/batch_size)
  # return data iterator and steps per epoch
  return data_iter, steps_per_epoch

# %%
# define ConvNet model
def model(optimizer=Adam(), loss='categorical_crossentropy'):
  # initialize model
  model = Sequential()
  # add layers to model
  model.add(Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same', input_shape=(32, 32, 3)))
  model.add(BatchNormalization())
  model.add(Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
  model.add(BatchNormalization())
  model.add(MaxPooling2D((2, 2)))
  model.add(Dropout(0.2))
  model.add(Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
  model.add(BatchNormalization())
  model.add(Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
  model.add(BatchNormalization())
  model.add(MaxPooling2D((2, 2)))
  model.add(Dropout(0.3))
  model.add(Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
  model.add(BatchNormalization())
  model.add(Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
  model.add(BatchNormalization())
  model.add(MaxPooling2D((2, 2)))
  model.add(Dropout(0.4))
  model.add(Flatten())
  model.add(Dense(128, activation='relu', kernel_initializer='he_uniform'))
  model.add(BatchNormalization())
  model.add(Dropout(0.5))
  model.add(Dense(10, activation='softmax'))
  # compile model
  model.compile(optimizer=optimizer, loss=loss, metrics=['accuracy'])
  return model

# %%
# display training metrics and plot learning curves
def training_summary(history, loss, accuracy, test=False):
  # define x-axis of plots
  epochs = np.arange(len(history.history['loss'])) + 1
  # determine if evaluating performance on test set or validation set
  label = 'test' if test else 'validation'
  plt.figure(figsize=(15,30))
  # plot losses
  plt.subplot(621)
  plt.tight_layout()
  plt.title('Cross-Entropy Loss', fontsize=16)
  plt.xlabel('Epoch', fontsize=14)
  plt.ylabel('Loss', fontsize=14)
  plt.plot(epochs, history.history['loss'], color='blue', label='train')
  plt.plot(epochs, history.history['val_loss'], color='orange', label=label)
  plt.legend(loc='upper left')
  # plot accuracies
  plt.subplot(622)
  plt.tight_layout()
  plt.title('Classification Accuracy', fontsize=16)
  plt.xlabel('Epoch', fontsize=14)
  plt.ylabel('Accuracy', fontsize=14)
  plt.plot(epochs, history.history['accuracy'], color='blue', label='train')
  plt.plot(epochs, history.history['val_accuracy'], color='orange', label=label)
  plt.legend(loc='upper left')
  # print final loss and accuracy
  print(f'{label} loss: {loss:.3f} - {label} accuracy: {accuracy:.3f}')

# %%
def predict(model, examples, label_map, transform=lambda x: (255*x).astype('uint8')):
  # make predictions based on example data
  predictions = [label_map[np.argmax(prediction)] for prediction in model.predict(examples)]
  # denormalize image data
  examples = transform(examples)
  for i in range(len(predictions)):
    plt.subplot(6,2,i+3)
    plt.tight_layout()
    # remove axis labels and ticks
    ax = plt.gca().axes
    ax.xaxis.set_ticks([])
    ax.yaxis.set_ticks([])
    # display prediction
    plt.xlabel(predictions[i], fontsize=16)
    # display image
    plt.imshow(examples[i])

# %%
# train the model and evaluate its performance
def train(data_loader, model, optimizer=Adam(), loss='categorical_crossentropy', epochs=100, batch_size=64, test=False, verbose=False):
  # load dataset
  trainX, trainY, valX, valY = data_loader(test=test)
  # define model
  model = model(optimizer=optimizer, loss=loss)
  # fit model
  data_iter, steps_per_epoch = data_generator(trainX, trainY, batch_size=batch_size)
  history = model.fit(data_iter, steps_per_epoch=steps_per_epoch, epochs=epochs, batch_size=batch_size, validation_data=(valX, valY), verbose=verbose)
  # evaluate model
  loss, acc = model.evaluate(valX, valY)
  # summarize training
  training_summary(history, loss, acc, test=test)
  # make predictions
  label_map = {0:'airplane', 1:'automobile', 2:'bird', 3:'cat', 4:'deer', 5:'dog', 6:'frog', 7:'horse', 8:'ship', 9:'truck'}
  predict(model, valX[:10], label_map)

# %%
train(data_loader=data_loader, model=model, epochs=150, test=True, verbose=True)
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 4s 0us/step
# 170508288/170498071 [==============================] - 4s 0us/step
# Epoch 1/150
# 781/781 [==============================] - 58s 59ms/step - loss: 1.7561 - accuracy: 0.3937 - val_loss: 1.3294 - val_accuracy: 0.5275
# Epoch 2/150
# 781/781 [==============================] - 48s 61ms/step - loss: 1.2534 - accuracy: 0.5510 - val_loss: 0.9883 - val_accuracy: 0.6525
# Epoch 3/150
# 781/781 [==============================] - 46s 59ms/step - loss: 1.0547 - accuracy: 0.6260 - val_loss: 0.8376 - val_accuracy: 0.7078
# Epoch 4/150
# 781/781 [==============================] - 46s 59ms/step - loss: 0.9474 - accuracy: 0.6704 - val_loss: 0.8394 - val_accuracy: 0.7035
# Epoch 5/150
# 781/781 [==============================] - 45s 58ms/step - loss: 0.8678 - accuracy: 0.7003 - val_loss: 0.7657 - val_accuracy: 0.7371
# Epoch 6/150
# 781/781 [==============================] - 46s 58ms/step - loss: 0.8138 - accuracy: 0.7182 - val_loss: 0.7099 - val_accuracy: 0.7529
# Epoch 7/150
# 781/781 [==============================] - 45s 58ms/step - loss: 0.7526 - accuracy: 0.7402 - val_loss: 0.6614 - val_accuracy: 0.7737
# Epoch 8/150
# 781/781 [==============================] - 45s 58ms/step - loss: 0.7199 - accuracy: 0.7540 - val_loss: 0.5994 - val_accuracy: 0.7937
# Epoch 9/150
# 781/781 [==============================] - 45s 58ms/step - loss: 0.6874 - accuracy: 0.7644 - val_loss: 0.5917 - val_accuracy: 0.8041
# Epoch 10/150
# 781/781 [==============================] - 46s 58ms/step - loss: 0.6537 - accuracy: 0.7786 - val_loss: 0.6231 - val_accuracy: 0.7857
# Epoch 11/150
# 781/781 [==============================] - 46s 59ms/step - loss: 0.6315 - accuracy: 0.7855 - val_loss: 0.5330 - val_accuracy: 0.8195
# Epoch 12/150
# 781/781 [==============================] - 46s 59ms/step - loss: 0.6178 - accuracy: 0.7905 - val_loss: 0.5572 - val_accuracy: 0.8067
# Epoch 13/150
# 781/781 [==============================] - 46s 58ms/step - loss: 0.5914 - accuracy: 0.8007 - val_loss: 0.5646 - val_accuracy: 0.8088
# Epoch 14/150
# 781/781 [==============================] - 45s 58ms/step - loss: 0.5771 - accuracy: 0.8025 - val_loss: 0.6036 - val_accuracy: 0.7977
# Epoch 15/150
# 781/781 [==============================] - 45s 58ms/step - loss: 0.5627 - accuracy: 0.8098 - val_loss: 0.5037 - val_accuracy: 0.8299
# Epoch 16/150
# 781/781 [==============================] - 45s 58ms/step - loss: 0.5458 - accuracy: 0.8142 - val_loss: 0.5290 - val_accuracy: 0.8212
# Epoch 17/150
# 781/781 [==============================] - 45s 58ms/step - loss: 0.5364 - accuracy: 0.8176 - val_loss: 0.5134 - val_accuracy: 0.8287
# Epoch 18/150
# 781/781 [==============================] - 46s 59ms/step - loss: 0.5288 - accuracy: 0.8212 - val_loss: 0.4853 - val_accuracy: 0.8362
# Epoch 19/150
# 781/781 [==============================] - 45s 58ms/step - loss: 0.5109 - accuracy: 0.8268 - val_loss: 0.5183 - val_accuracy: 0.8235
# Epoch 20/150
# 781/781 [==============================] - 45s 58ms/step - loss: 0.5057 - accuracy: 0.8273 - val_loss: 0.4987 - val_accuracy: 0.8339
# Epoch 21/150
# 781/781 [==============================] - 46s 59ms/step - loss: 0.4994 - accuracy: 0.8314 - val_loss: 0.4927 - val_accuracy: 0.8343
# Epoch 22/150
# 781/781 [==============================] - 46s 59ms/step - loss: 0.4860 - accuracy: 0.8349 - val_loss: 0.4896 - val_accuracy: 0.8336
# Epoch 23/150
# 781/781 [==============================] - 46s 59ms/step - loss: 0.4770 - accuracy: 0.8385 - val_loss: 0.4988 - val_accuracy: 0.8351
# Epoch 24/150
# 781/781 [==============================] - 46s 59ms/step - loss: 0.4761 - accuracy: 0.8391 - val_loss: 0.4346 - val_accuracy: 0.8536
# Epoch 25/150
# 781/781 [==============================] - 45s 58ms/step - loss: 0.4685 - accuracy: 0.8408 - val_loss: 0.4679 - val_accuracy: 0.8407
# Epoch 26/150
# 781/781 [==============================] - 45s 57ms/step - loss: 0.4637 - accuracy: 0.8424 - val_loss: 0.4941 - val_accuracy: 0.8326
# Epoch 27/150
# 781/781 [==============================] - 45s 57ms/step - loss: 0.4589 - accuracy: 0.8435 - val_loss: 0.4671 - val_accuracy: 0.8436
# Epoch 28/150
# 781/781 [==============================] - 44s 57ms/step - loss: 0.4474 - accuracy: 0.8484 - val_loss: 0.4110 - val_accuracy: 0.8579
# Epoch 29/150
# 781/781 [==============================] - 46s 59ms/step - loss: 0.4455 - accuracy: 0.8480 - val_loss: 0.4321 - val_accuracy: 0.8572
# Epoch 30/150
# 781/781 [==============================] - 46s 59ms/step - loss: 0.4391 - accuracy: 0.8514 - val_loss: 0.4657 - val_accuracy: 0.8460
# Epoch 31/150
# 781/781 [==============================] - 46s 59ms/step - loss: 0.4354 - accuracy: 0.8512 - val_loss: 0.3685 - val_accuracy: 0.8738
# Epoch 32/150
# 781/781 [==============================] - 45s 58ms/step - loss: 0.4307 - accuracy: 0.8520 - val_loss: 0.4806 - val_accuracy: 0.8428
# Epoch 33/150
# 781/781 [==============================] - 45s 58ms/step - loss: 0.4211 - accuracy: 0.8559 - val_loss: 0.3868 - val_accuracy: 0.8727
# Epoch 34/150
# 781/781 [==============================] - 45s 58ms/step - loss: 0.4247 - accuracy: 0.8561 - val_loss: 0.3752 - val_accuracy: 0.8701
# Epoch 35/150
# 781/781 [==============================] - 45s 58ms/step - loss: 0.4186 - accuracy: 0.8572 - val_loss: 0.5481 - val_accuracy: 0.8218
# Epoch 36/150
# 781/781 [==============================] - 45s 58ms/step - loss: 0.4089 - accuracy: 0.8604 - val_loss: 0.4185 - val_accuracy: 0.8616
# Epoch 37/150
# 781/781 [==============================] - 45s 58ms/step - loss: 0.4103 - accuracy: 0.8607 - val_loss: 0.4168 - val_accuracy: 0.8637
# Epoch 38/150
# 781/781 [==============================] - 45s 58ms/step - loss: 0.4122 - accuracy: 0.8603 - val_loss: 0.3867 - val_accuracy: 0.8730
# Epoch 39/150
# 781/781 [==============================] - 45s 58ms/step - loss: 0.3975 - accuracy: 0.8648 - val_loss: 0.4274 - val_accuracy: 0.8626
# Epoch 40/150
# 781/781 [==============================] - 46s 59ms/step - loss: 0.4042 - accuracy: 0.8631 - val_loss: 0.3709 - val_accuracy: 0.8769
# Epoch 41/150
# 781/781 [==============================] - 46s 59ms/step - loss: 0.3978 - accuracy: 0.8643 - val_loss: 0.3984 - val_accuracy: 0.8715
# Epoch 42/150
# 781/781 [==============================] - 45s 57ms/step - loss: 0.3921 - accuracy: 0.8672 - val_loss: 0.3904 - val_accuracy: 0.8756
# Epoch 43/150
# 781/781 [==============================] - 45s 58ms/step - loss: 0.3960 - accuracy: 0.8650 - val_loss: 0.3852 - val_accuracy: 0.8719
# Epoch 44/150
# 781/781 [==============================] - 45s 58ms/step - loss: 0.3915 - accuracy: 0.8678 - val_loss: 0.3751 - val_accuracy: 0.8792
# Epoch 45/150
# 781/781 [==============================] - 45s 58ms/step - loss: 0.3854 - accuracy: 0.8690 - val_loss: 0.3655 - val_accuracy: 0.8789
# Epoch 46/150
# 781/781 [==============================] - 45s 58ms/step - loss: 0.3836 - accuracy: 0.8697 - val_loss: 0.3796 - val_accuracy: 0.8735
# Epoch 47/150
# 781/781 [==============================] - 45s 58ms/step - loss: 0.3814 - accuracy: 0.8723 - val_loss: 0.3829 - val_accuracy: 0.8723
# Epoch 48/150
# 781/781 [==============================] - 47s 60ms/step - loss: 0.3804 - accuracy: 0.8697 - val_loss: 0.4111 - val_accuracy: 0.8679
# Epoch 49/150
# 781/781 [==============================] - 46s 58ms/step - loss: 0.3774 - accuracy: 0.8704 - val_loss: 0.3452 - val_accuracy: 0.8858
# Epoch 50/150
# 781/781 [==============================] - 45s 58ms/step - loss: 0.3765 - accuracy: 0.8715 - val_loss: 0.3920 - val_accuracy: 0.8730
# Epoch 51/150
# 781/781 [==============================] - 45s 58ms/step - loss: 0.3633 - accuracy: 0.8770 - val_loss: 0.3538 - val_accuracy: 0.8840
# Epoch 52/150
# 781/781 [==============================] - 45s 58ms/step - loss: 0.3684 - accuracy: 0.8742 - val_loss: 0.3559 - val_accuracy: 0.8800
# Epoch 53/150
# 781/781 [==============================] - 45s 58ms/step - loss: 0.3633 - accuracy: 0.8767 - val_loss: 0.3451 - val_accuracy: 0.8850
# Epoch 54/150
# 781/781 [==============================] - 46s 60ms/step - loss: 0.3613 - accuracy: 0.8764 - val_loss: 0.3811 - val_accuracy: 0.8760
# Epoch 55/150
# 781/781 [==============================] - 45s 58ms/step - loss: 0.3621 - accuracy: 0.8765 - val_loss: 0.3867 - val_accuracy: 0.8762
# Epoch 56/150
# 781/781 [==============================] - 46s 59ms/step - loss: 0.3580 - accuracy: 0.8788 - val_loss: 0.3448 - val_accuracy: 0.8874
# Epoch 57/150
# 781/781 [==============================] - 45s 58ms/step - loss: 0.3558 - accuracy: 0.8788 - val_loss: 0.4002 - val_accuracy: 0.8721
# Epoch 58/150
# 781/781 [==============================] - 45s 58ms/step - loss: 0.3551 - accuracy: 0.8798 - val_loss: 0.3489 - val_accuracy: 0.8870
# Epoch 59/150
# 781/781 [==============================] - 45s 58ms/step - loss: 0.3526 - accuracy: 0.8810 - val_loss: 0.3241 - val_accuracy: 0.8891
# Epoch 60/150
# 781/781 [==============================] - 45s 58ms/step - loss: 0.3481 - accuracy: 0.8807 - val_loss: 0.3805 - val_accuracy: 0.8738
# Epoch 61/150
# 781/781 [==============================] - 45s 58ms/step - loss: 0.3515 - accuracy: 0.8811 - val_loss: 0.3868 - val_accuracy: 0.8764
# Epoch 62/150
# 781/781 [==============================] - 45s 58ms/step - loss: 0.3511 - accuracy: 0.8803 - val_loss: 0.3549 - val_accuracy: 0.8838
# Epoch 63/150
# 781/781 [==============================] - 45s 58ms/step - loss: 0.3499 - accuracy: 0.8820 - val_loss: 0.3928 - val_accuracy: 0.8727
# Epoch 64/150
# 781/781 [==============================] - 46s 59ms/step - loss: 0.3470 - accuracy: 0.8808 - val_loss: 0.3228 - val_accuracy: 0.8939
# Epoch 65/150
# 781/781 [==============================] - 47s 60ms/step - loss: 0.3430 - accuracy: 0.8831 - val_loss: 0.3300 - val_accuracy: 0.8908
# Epoch 66/150
# 781/781 [==============================] - 46s 58ms/step - loss: 0.3401 - accuracy: 0.8836 - val_loss: 0.3581 - val_accuracy: 0.8831
# Epoch 67/150
# 781/781 [==============================] - 46s 59ms/step - loss: 0.3407 - accuracy: 0.8831 - val_loss: 0.3643 - val_accuracy: 0.8828
# Epoch 68/150
# 781/781 [==============================] - 45s 58ms/step - loss: 0.3369 - accuracy: 0.8850 - val_loss: 0.4246 - val_accuracy: 0.8623
# Epoch 69/150
# 781/781 [==============================] - 46s 59ms/step - loss: 0.3361 - accuracy: 0.8849 - val_loss: 0.3689 - val_accuracy: 0.8799
# Epoch 70/150
# 781/781 [==============================] - 46s 59ms/step - loss: 0.3383 - accuracy: 0.8857 - val_loss: 0.3626 - val_accuracy: 0.8836
# Epoch 71/150
# 781/781 [==============================] - 45s 58ms/step - loss: 0.3327 - accuracy: 0.8853 - val_loss: 0.3296 - val_accuracy: 0.8913
# Epoch 72/150
# 781/781 [==============================] - 46s 59ms/step - loss: 0.3284 - accuracy: 0.8889 - val_loss: 0.3817 - val_accuracy: 0.8728
# Epoch 73/150
# 781/781 [==============================] - 45s 58ms/step - loss: 0.3347 - accuracy: 0.8869 - val_loss: 0.3514 - val_accuracy: 0.8836
# Epoch 74/150
# 781/781 [==============================] - 43s 56ms/step - loss: 0.3313 - accuracy: 0.8868 - val_loss: 0.3269 - val_accuracy: 0.8917
# Epoch 75/150
# 781/781 [==============================] - 44s 56ms/step - loss: 0.3275 - accuracy: 0.8876 - val_loss: 0.3580 - val_accuracy: 0.8894
# Epoch 76/150
# 781/781 [==============================] - 45s 58ms/step - loss: 0.3248 - accuracy: 0.8892 - val_loss: 0.3864 - val_accuracy: 0.8728
# Epoch 77/150
# 781/781 [==============================] - 45s 58ms/step - loss: 0.3300 - accuracy: 0.8876 - val_loss: 0.3567 - val_accuracy: 0.8847
# Epoch 78/150
# 781/781 [==============================] - 44s 56ms/step - loss: 0.3244 - accuracy: 0.8879 - val_loss: 0.3916 - val_accuracy: 0.8712
# Epoch 79/150
# 781/781 [==============================] - 44s 56ms/step - loss: 0.3230 - accuracy: 0.8901 - val_loss: 0.3376 - val_accuracy: 0.8917
# Epoch 80/150
# 781/781 [==============================] - 45s 58ms/step - loss: 0.3228 - accuracy: 0.8902 - val_loss: 0.3764 - val_accuracy: 0.8791
# Epoch 81/150
# 781/781 [==============================] - 47s 60ms/step - loss: 0.3191 - accuracy: 0.8910 - val_loss: 0.3709 - val_accuracy: 0.8788
# Epoch 82/150
# 781/781 [==============================] - 46s 59ms/step - loss: 0.3186 - accuracy: 0.8905 - val_loss: 0.3464 - val_accuracy: 0.8909
# Epoch 83/150
# 781/781 [==============================] - 44s 57ms/step - loss: 0.3225 - accuracy: 0.8887 - val_loss: 0.3522 - val_accuracy: 0.8858
# Epoch 84/150
# 781/781 [==============================] - 46s 58ms/step - loss: 0.3181 - accuracy: 0.8913 - val_loss: 0.3661 - val_accuracy: 0.8826
# Epoch 85/150
# 781/781 [==============================] - 44s 56ms/step - loss: 0.3150 - accuracy: 0.8917 - val_loss: 0.3430 - val_accuracy: 0.8902
# Epoch 86/150
# 781/781 [==============================] - 44s 56ms/step - loss: 0.3173 - accuracy: 0.8920 - val_loss: 0.3396 - val_accuracy: 0.8936
# Epoch 87/150
# 781/781 [==============================] - 44s 57ms/step - loss: 0.3133 - accuracy: 0.8924 - val_loss: 0.4095 - val_accuracy: 0.8696
# Epoch 88/150
# 781/781 [==============================] - 44s 57ms/step - loss: 0.3150 - accuracy: 0.8926 - val_loss: 0.3455 - val_accuracy: 0.8873
# Epoch 89/150
# 781/781 [==============================] - 45s 57ms/step - loss: 0.3165 - accuracy: 0.8922 - val_loss: 0.3145 - val_accuracy: 0.8975
# Epoch 90/150
# 781/781 [==============================] - 47s 60ms/step - loss: 0.3068 - accuracy: 0.8947 - val_loss: 0.3431 - val_accuracy: 0.8895
# Epoch 91/150
# 781/781 [==============================] - 45s 57ms/step - loss: 0.3109 - accuracy: 0.8933 - val_loss: 0.3193 - val_accuracy: 0.8985
# Epoch 92/150
# 781/781 [==============================] - 45s 57ms/step - loss: 0.3087 - accuracy: 0.8948 - val_loss: 0.3571 - val_accuracy: 0.8848
# Epoch 93/150
# 781/781 [==============================] - 44s 57ms/step - loss: 0.3106 - accuracy: 0.8928 - val_loss: 0.3790 - val_accuracy: 0.8806
# Epoch 94/150
# 781/781 [==============================] - 44s 56ms/step - loss: 0.3086 - accuracy: 0.8941 - val_loss: 0.3507 - val_accuracy: 0.8857
# Epoch 95/150
# 781/781 [==============================] - 44s 57ms/step - loss: 0.3067 - accuracy: 0.8965 - val_loss: 0.3700 - val_accuracy: 0.8843
# Epoch 96/150
# 781/781 [==============================] - 46s 58ms/step - loss: 0.3016 - accuracy: 0.8966 - val_loss: 0.3257 - val_accuracy: 0.8961
# Epoch 97/150
# 781/781 [==============================] - 44s 57ms/step - loss: 0.2991 - accuracy: 0.8969 - val_loss: 0.3641 - val_accuracy: 0.8875
# Epoch 98/150
# 781/781 [==============================] - 44s 57ms/step - loss: 0.2999 - accuracy: 0.8983 - val_loss: 0.3419 - val_accuracy: 0.8916
# Epoch 99/150
# 781/781 [==============================] - 47s 60ms/step - loss: 0.3028 - accuracy: 0.8971 - val_loss: 0.3409 - val_accuracy: 0.8912
# Epoch 100/150
# 781/781 [==============================] - 46s 58ms/step - loss: 0.2971 - accuracy: 0.8984 - val_loss: 0.3421 - val_accuracy: 0.8894
# Epoch 101/150
# 781/781 [==============================] - 45s 58ms/step - loss: 0.2997 - accuracy: 0.8980 - val_loss: 0.4013 - val_accuracy: 0.8721
# Epoch 102/150
# 781/781 [==============================] - 46s 59ms/step - loss: 0.2986 - accuracy: 0.8979 - val_loss: 0.3832 - val_accuracy: 0.8793
# Epoch 103/150
# 781/781 [==============================] - 45s 58ms/step - loss: 0.2993 - accuracy: 0.8979 - val_loss: 0.3619 - val_accuracy: 0.8828
# Epoch 104/150
# 781/781 [==============================] - 46s 59ms/step - loss: 0.2963 - accuracy: 0.8972 - val_loss: 0.3533 - val_accuracy: 0.8842
# Epoch 105/150
# 781/781 [==============================] - 46s 59ms/step - loss: 0.3035 - accuracy: 0.8971 - val_loss: 0.3245 - val_accuracy: 0.8969
# Epoch 106/150
# 781/781 [==============================] - 46s 58ms/step - loss: 0.2941 - accuracy: 0.8982 - val_loss: 0.3288 - val_accuracy: 0.8968
# Epoch 107/150
# 781/781 [==============================] - 47s 60ms/step - loss: 0.2937 - accuracy: 0.8992 - val_loss: 0.3425 - val_accuracy: 0.8891
# Epoch 108/150
# 781/781 [==============================] - 47s 60ms/step - loss: 0.2925 - accuracy: 0.8990 - val_loss: 0.3387 - val_accuracy: 0.8915
# Epoch 109/150
# 781/781 [==============================] - 45s 58ms/step - loss: 0.2928 - accuracy: 0.8994 - val_loss: 0.3453 - val_accuracy: 0.8894
# Epoch 110/150
# 781/781 [==============================] - 45s 58ms/step - loss: 0.2919 - accuracy: 0.8990 - val_loss: 0.3049 - val_accuracy: 0.9039
# Epoch 111/150
# 781/781 [==============================] - 45s 57ms/step - loss: 0.2903 - accuracy: 0.8990 - val_loss: 0.3279 - val_accuracy: 0.8949
# Epoch 112/150
# 781/781 [==============================] - 45s 57ms/step - loss: 0.2908 - accuracy: 0.8997 - val_loss: 0.3719 - val_accuracy: 0.8846
# Epoch 113/150
# 781/781 [==============================] - 45s 57ms/step - loss: 0.2888 - accuracy: 0.9007 - val_loss: 0.3572 - val_accuracy: 0.8874
# Epoch 114/150
# 781/781 [==============================] - 45s 58ms/step - loss: 0.2883 - accuracy: 0.9013 - val_loss: 0.3443 - val_accuracy: 0.8910
# Epoch 115/150
# 781/781 [==============================] - 46s 59ms/step - loss: 0.2897 - accuracy: 0.9012 - val_loss: 0.3438 - val_accuracy: 0.8878
# Epoch 116/150
# 781/781 [==============================] - 45s 58ms/step - loss: 0.2847 - accuracy: 0.9021 - val_loss: 0.3253 - val_accuracy: 0.8962
# Epoch 117/150
# 781/781 [==============================] - 46s 59ms/step - loss: 0.2820 - accuracy: 0.9040 - val_loss: 0.3072 - val_accuracy: 0.9004
# Epoch 118/150
# 781/781 [==============================] - 44s 57ms/step - loss: 0.2865 - accuracy: 0.9023 - val_loss: 0.3118 - val_accuracy: 0.8987
# Epoch 119/150
# 781/781 [==============================] - 44s 56ms/step - loss: 0.2876 - accuracy: 0.9018 - val_loss: 0.3176 - val_accuracy: 0.8988
# Epoch 120/150
# 781/781 [==============================] - 47s 60ms/step - loss: 0.2875 - accuracy: 0.9029 - val_loss: 0.3685 - val_accuracy: 0.8803
# Epoch 121/150
# 781/781 [==============================] - 44s 57ms/step - loss: 0.2816 - accuracy: 0.9020 - val_loss: 0.3096 - val_accuracy: 0.8975
# Epoch 122/150
# 781/781 [==============================] - 47s 60ms/step - loss: 0.2866 - accuracy: 0.9013 - val_loss: 0.3382 - val_accuracy: 0.8877
# Epoch 123/150
# 781/781 [==============================] - 47s 60ms/step - loss: 0.2833 - accuracy: 0.9024 - val_loss: 0.3358 - val_accuracy: 0.8931
# Epoch 124/150
# 781/781 [==============================] - 46s 59ms/step - loss: 0.2790 - accuracy: 0.9041 - val_loss: 0.3252 - val_accuracy: 0.8969
# Epoch 125/150
# 781/781 [==============================] - 46s 59ms/step - loss: 0.2818 - accuracy: 0.9041 - val_loss: 0.3292 - val_accuracy: 0.8956
# Epoch 126/150
# 781/781 [==============================] - 47s 60ms/step - loss: 0.2815 - accuracy: 0.9034 - val_loss: 0.3480 - val_accuracy: 0.8906
# Epoch 127/150
# 781/781 [==============================] - 45s 57ms/step - loss: 0.2802 - accuracy: 0.9045 - val_loss: 0.3353 - val_accuracy: 0.8950
# Epoch 128/150
# 781/781 [==============================] - 45s 57ms/step - loss: 0.2797 - accuracy: 0.9045 - val_loss: 0.3349 - val_accuracy: 0.8946
# Epoch 129/150
# 781/781 [==============================] - 46s 58ms/step - loss: 0.2763 - accuracy: 0.9055 - val_loss: 0.3232 - val_accuracy: 0.8986
# Epoch 130/150
# 781/781 [==============================] - 46s 59ms/step - loss: 0.2797 - accuracy: 0.9041 - val_loss: 0.3214 - val_accuracy: 0.8952
# Epoch 131/150
# 781/781 [==============================] - 47s 61ms/step - loss: 0.2774 - accuracy: 0.9047 - val_loss: 0.3253 - val_accuracy: 0.8968
# Epoch 132/150
# 781/781 [==============================] - 47s 60ms/step - loss: 0.2793 - accuracy: 0.9037 - val_loss: 0.3094 - val_accuracy: 0.8990
# Epoch 133/150
# 781/781 [==============================] - 46s 58ms/step - loss: 0.2709 - accuracy: 0.9064 - val_loss: 0.3755 - val_accuracy: 0.8870
# Epoch 134/150
# 781/781 [==============================] - 47s 60ms/step - loss: 0.2730 - accuracy: 0.9062 - val_loss: 0.3133 - val_accuracy: 0.8998
# Epoch 135/150
# 781/781 [==============================] - 46s 59ms/step - loss: 0.2752 - accuracy: 0.9057 - val_loss: 0.3311 - val_accuracy: 0.8926
# Epoch 136/150
# 781/781 [==============================] - 45s 58ms/step - loss: 0.2727 - accuracy: 0.9056 - val_loss: 0.3271 - val_accuracy: 0.8960
# Epoch 137/150
# 781/781 [==============================] - 45s 57ms/step - loss: 0.2693 - accuracy: 0.9080 - val_loss: 0.3476 - val_accuracy: 0.8876
# Epoch 138/150
# 781/781 [==============================] - 46s 59ms/step - loss: 0.2735 - accuracy: 0.9067 - val_loss: 0.3265 - val_accuracy: 0.8968
# Epoch 139/150
# 781/781 [==============================] - 45s 58ms/step - loss: 0.2749 - accuracy: 0.9076 - val_loss: 0.4032 - val_accuracy: 0.8740
# Epoch 140/150
# 781/781 [==============================] - 47s 60ms/step - loss: 0.2696 - accuracy: 0.9063 - val_loss: 0.3050 - val_accuracy: 0.9009
# Epoch 141/150
# 781/781 [==============================] - 45s 58ms/step - loss: 0.2712 - accuracy: 0.9060 - val_loss: 0.3446 - val_accuracy: 0.8915
# Epoch 142/150
# 781/781 [==============================] - 47s 60ms/step - loss: 0.2698 - accuracy: 0.9063 - val_loss: 0.3582 - val_accuracy: 0.8881
# Epoch 143/150
# 781/781 [==============================] - 46s 59ms/step - loss: 0.2683 - accuracy: 0.9064 - val_loss: 0.3294 - val_accuracy: 0.8975
# Epoch 144/150
# 781/781 [==============================] - 44s 56ms/step - loss: 0.2701 - accuracy: 0.9080 - val_loss: 0.3511 - val_accuracy: 0.8872
# Epoch 145/150
# 781/781 [==============================] - 46s 59ms/step - loss: 0.2651 - accuracy: 0.9085 - val_loss: 0.3192 - val_accuracy: 0.8973
# Epoch 146/150
# 781/781 [==============================] - 45s 58ms/step - loss: 0.2680 - accuracy: 0.9082 - val_loss: 0.3029 - val_accuracy: 0.9020
# Epoch 147/150
# 781/781 [==============================] - 45s 57ms/step - loss: 0.2672 - accuracy: 0.9079 - val_loss: 0.3438 - val_accuracy: 0.8907
# Epoch 148/150
# 781/781 [==============================] - 46s 59ms/step - loss: 0.2665 - accuracy: 0.9072 - val_loss: 0.3159 - val_accuracy: 0.8981
# Epoch 149/150
# 781/781 [==============================] - 46s 59ms/step - loss: 0.2604 - accuracy: 0.9112 - val_loss: 0.3306 - val_accuracy: 0.8958
# Epoch 150/150
# 781/781 [==============================] - 44s 57ms/step - loss: 0.2649 - accuracy: 0.9101 - val_loss: 0.3380 - val_accuracy: 0.8931
# 313/313 [==============================] - 2s 7ms/step - loss: 0.3380 - accuracy: 0.8931
# test loss: 0.338 - test accuracy: 0.893
